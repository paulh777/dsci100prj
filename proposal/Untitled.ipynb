# %%
library(tidyverse)
library(tidymodels)

options(scipen = 999)

genre_data = read_csv("https://raw.githubusercontent.com/paulh777/dsci100prj/main/proposal/data_by_genres.csv")

#Select the columns relevant to research
popularity_data = genre_data %>%
    select(duration_ms, liveness, loudness, speechiness, tempo, popularity)

popularity_data
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘tidymodels’ was built under R version 4.0.2”
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.1 ──
#
# ✔ broom     0.7.0      ✔ recipes   0.1.13
# ✔ dials     0.0.9      ✔ rsample   0.0.7
# ✔ infer     0.5.4      ✔ tune      0.1.1
# ✔ modeldata 0.0.2      ✔ workflows 0.2.0
# ✔ parsnip   0.1.3      ✔ yardstick 0.0.7
#
# Warning message:
# “package ‘broom’ was built under R version 4.0.2”
# Warning message:
# “package ‘dials’ was built under R version 4.0.2”
# Warning message:
# “package ‘infer’ was built under R version 4.0.3”
# Warning message:
# “package ‘modeldata’ was built under R version 4.0.1”
# Warning message:
# “package ‘parsnip’ was built under R version 4.0.2”
# Warning message:
# “package ‘recipes’ was built under R version 4.0.1”
# Warning message:
# “package ‘tune’ was built under R version 4.0.2”
# Warning message:
# “package ‘workflows’ was built under R version 4.0.2”
# Warning message:
# “package ‘yardstick’ was built under R version 4.0.2”
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
#
# Parsed with column specification:
# cols(
#   mode = col_double(),
#   genres = col_character(),
#   acousticness = col_double(),
#   danceability = col_double(),
#   duration_ms = col_double(),
#   energy = col_double(),
#   instrumentalness = col_double(),
#   liveness = col_double(),
#   loudness = col_double(),
#   speechiness = col_double(),
#   tempo = col_double(),
#   valence = col_double(),
#   popularity = col_double(),
#   key = col_double()
# )
#      duration_ms liveness   loudness   speechiness tempo     popularity
# 1     160297.7   0.36160000 -31.514333 0.04056667   75.33650 27.833333
# 2    1048887.3   0.13100000 -16.854000 0.07681667  120.28567 52.500000
# 3     115177.0   0.12600000  -9.180000 0.04700000  133.44400 48.000000
# 4     232880.9   0.21869585 -12.288965 0.10787156  112.85735 20.859882
# 5     190628.5   0.17225414 -12.479387 0.08285144  112.11036 45.820071
# 6     343196.5   0.11806667 -15.472083 0.04651667  127.88575 43.500000
# 7     229936.2   0.09965333  -7.918000 0.11637333  112.41380 58.933333
# 8     231849.2   0.16854292  -7.349328 0.21425770  108.24499 39.790702
# 9     164000.0   0.07940000 -14.899000 0.07270000  109.13100 39.000000
# 10    167061.6   0.16030000 -14.487063 0.07853750  112.87244 21.937500
# 11    297188.1   0.23348846  -9.381200 0.05585538  126.49209 46.638462
# 12    259203.9   0.23045146 -11.433073 0.06759985  125.65952 32.675955
# 13    221160.0   0.18500000  -6.775000 0.04490000  132.68700 62.000000
# 14    185040.3   0.26100618 -20.964565 0.08061774  104.07463  9.342524
# 15    204321.3   0.18309821 -12.554905 0.06881536  113.28452 23.746060
# 16    235379.8   0.15775050  -9.297248 0.04177066  117.88742 53.115505
# 2970 206320.0    0.10800000  -5.985000 0.08130000  119.0380  58.00000
# 2971 306072.8    0.08967778 -10.289222 0.03877778  101.9652  46.66667
# 2972 198417.3    0.17966667 -11.453333 0.34866667   91.2780   0.00000
# 2973 171671.7    0.25587659  -9.854825 0.05049127  126.3661  30.26190

# %%
#Split
popularity_split = initial_split(popularity_data, prop = 0.5, strata = popularity)
popularity_training = training(popularity_split)
popularity_testing = testing(popularity_split)

# %%
#Tables Relevant to Research
popularity_max = popularity_training %>%
    map_df(max, na.rm=TRUE)

popularity_min = popularity_training %>%
    map_df(min, na.rm=TRUE)

popularity_mean = popularity_training %>%
    map_df(mean, na.rm=TRUE)

popularity_median = popularity_training %>%
    map_df(median, na.rm=TRUE)

popularity_sd = popularity_training %>%
    map_df(sd, na.rm=TRUE)

    
popularity_max = popularity_max %>%
    pivot_longer(
        cols = duration_ms:popularity,
        names_to = "variable",
        values_to = "max"
    )

popularity_min = popularity_min %>%
    pivot_longer(
        cols = duration_ms:popularity,
        names_to = "remove1",
        values_to = "min"
    )

popularity_mean = popularity_mean %>%
    pivot_longer(
        cols = duration_ms:popularity,
        names_to = "remove2",
        values_to = "mean"
    )

popularity_median = popularity_median %>%
    pivot_longer(
        cols = duration_ms:popularity,
        names_to = "remove3",
        values_to = "median"
    )

popularity_sd = popularity_sd %>%
    pivot_longer(
        cols = duration_ms:popularity,
        names_to = "remove4",
        values_to = "standard_deviation"
    )


popularity_table = popularity_max %>%
bind_cols(popularity_min)%>%
bind_cols(popularity_mean)%>%
bind_cols(popularity_median)%>%
bind_cols(popularity_sd)%>%
select(variable,max,min,mean,median,standard_deviation)

popularity_table
# Out:
#   variable    max           min        mean            median
# 1 duration_ms 1622000.00000 42813.0000 250277.99504598 236450.67148199
# 2 liveness          0.88300     0.0239      0.19213822      0.17911911
# 3 loudness          0.06000   -41.8250    -10.46719783     -9.08404435
# 4 speechiness       0.90350     0.0238      0.08445806      0.06008013
# 5 tempo           198.06000    59.0475    119.54559491    119.32658735
# 6 popularity       80.66667     0.0000     39.87779010     43.06300660
#   standard_deviation
# 1 89890.61408356
# 2     0.09244850
# 3     5.43601083
# 4     0.07828599
# 5    17.72235138
# 6    17.00249349

# %%
#Visualizations Relevant to Research



duration_plot <- ggplot(popularity_training, aes(x = duration_ms, y = popularity)) +
    geom_point() +
    labs(x="Duration (ms)", y= "Popularity Scale")

duration_plot #clear outlier (may need to delete)

liveness_plot <- ggplot(popularity_training, aes(x = liveness, y = popularity)) +
    geom_point() +
    labs(x="Liveness", y= "Popularity Scale")

liveness_plot

loudness_plot <- ggplot(popularity_training, aes(x = loudness, y = popularity)) +
    geom_point() +
    labs(x="loudness", y= "Popularity Scale")

loudness_plot

speechiness_plot <- ggplot(popularity_training, aes(x = speechiness, y = popularity)) +
    geom_point() +
    labs(x="speechiness", y= "Popularity Scale")

speechiness_plot

tempo_plot <- ggplot(popularity_training, aes(x = tempo, y = popularity)) +
    geom_point() +
    labs(x="tempo", y= "Popularity Scale")

tempo_plot
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
