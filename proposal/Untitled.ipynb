# %%
library(tidyverse)
library(tidymodels)

options(scipen = 999)

genre_data = read_csv("https://raw.githubusercontent.com/paulh777/dsci100prj/main/proposal/data_by_genres.csv")

#Select the columns relevant to research
popularity_data = genre_data %>%
    select(duration_ms, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, popularity)

popularity_data
# Out:
# Parsed with column specification:
# cols(
#   mode = col_double(),
#   genres = col_character(),
#   acousticness = col_double(),
#   danceability = col_double(),
#   duration_ms = col_double(),
#   energy = col_double(),
#   instrumentalness = col_double(),
#   liveness = col_double(),
#   loudness = col_double(),
#   speechiness = col_double(),
#   tempo = col_double(),
#   valence = col_double(),
#   popularity = col_double(),
#   key = col_double()
# )
#      duration_ms acousticness danceability energy     instrumentalness
# 1     160297.7   0.97933333   0.1628833    0.07131667 0.606833670000
# 2    1048887.3   0.49478000   0.2993333    0.45067833 0.477761666667
# 3     115177.0   0.76200000   0.7120000    0.81800000 0.876000000000
# 4     232880.9   0.65141702   0.5290926    0.41914607 0.205309189511
# 5     190628.5   0.67655730   0.5389612    0.31643357 0.003003441440
# 6     343196.5   0.45921000   0.5161667    0.44241667 0.849666666667
# 7     229936.2   0.34214667   0.6230000    0.52780000 0.333602612000
# 8     231849.2   0.24385406   0.6945709    0.64623464 0.024231262920
# 9     164000.0   0.32300000   0.5880000    0.39200000 0.441000000000
# 10    167061.6   0.44612500   0.6248125    0.37343750 0.193738393750
# 11    297188.1   0.06795054   0.6774000    0.72440308 0.385891030769
# 12    259203.9   0.25691451   0.4472390    0.58064929 0.150925677378
# 13    221160.0   0.00683000   0.6630000    0.92500000 0.703000000000
# 14    185040.3   0.91701911   0.4204583    0.23852434 0.616248413436
# 15    204321.3   0.76172354   0.6069148    0.36065929 0.098918136136
# 16    235379.8   0.49023503   0.5351083    0.47643992 0.033338280109
# 17    192332.1   0.40490002   0.5391116    0.61582415 0.061939951304
# 18    195036.0   0.61320079   0.5243968    0.41600265 0.321474921746
# 19    198400.0   0.22900000   0.4120000    0.93800000 0.000259000000
# 20    302906.1   0.43285714   0.5047143    0.52075000 0.000000000000
# 21    197331.5   0.65564838   0.4963276    0.38205358 0.118193574309
# 22    202876.6   0.78414333   0.5315000    0.31938333 0.000007450333
# 23    326503.9   0.41062857   0.6517143    0.65157143 0.000911163214
# 24    278581.3   0.95800000   0.4403333    0.32366667 0.400706666667
# 25    289556.3   0.32700000   0.6003636    0.78972727 0.257380690909
# 26    267673.4   0.24580000   0.7530000    0.66212500 0.003534624375
# 27    236075.3   0.13985650   0.6688958    0.61106250 0.093796150000
# 28    218619.1   0.92553414   0.2839757    0.14219492 0.432027261682
# 29    199565.2   0.14390025   0.6434583    0.76468182 0.007226254293
# 30    236572.3   0.32166667   0.6360000    0.57066667 0.133567333333
# ⋮    ⋮           ⋮            ⋮            ⋮          ⋮
# 2944 325951.7    0.54749794   0.5707906    0.4587730  0.253445930707
# 2945 358338.9    0.61037428   0.5009957    0.3212547  0.572384782198
# 2946 442902.7    0.95078571   0.3496429    0.1129000  0.878142857143
popularity_max = popularity_training %>%
    map_df(max, na.rm=TRUE)

popularity_min = popularity_training %>%
    map_df(min, na.rm=TRUE)

popularity_mean = popularity_training %>%
    map_df(mean, na.rm=TRUE)

popularity_median = popularity_training %>%
    map_df(median, na.rm=TRUE)

popularity_sd = popularity_training %>%
    map_df(sd, na.rm=TRUE)

    
popularity_max = popularity_max %>%
    pivot_longer(
        cols = duration_ms:popularity,
        names_to = "variable",
        values_to = "max"
    )

popularity_min = popularity_min %>%
    pivot_longer(
        cols = duration_ms:popularity,
        names_to = "remove1",
        values_to = "min"
    )

popularity_mean = popularity_mean %>%
    pivot_longer(
        cols = duration_ms:popularity,
        names_to = "remove2",
        values_to = "mean"
    )

popularity_median = popularity_median %>%
    pivot_longer(
        cols = duration_ms:popularity,
        names_to = "remove3",
        values_to = "median"
    )

popularity_sd = popularity_sd %>%
    pivot_longer(
        cols = duration_ms:popularity,
        names_to = "remove4",
        values_to = "standard_deviation"
    )


popularity_table = popularity_max %>%
bind_cols(popularity_min)%>%
bind_cols(popularity_mean)%>%
bind_cols(popularity_median)%>%
bind_cols(popularity_sd)%>%
select(variable,max,min,mean,median,standard_deviation)

popularity_table
# Out:
#   variable    max           min        mean            median
# 1 duration_ms 1622000.00000 30946.0000 251633.51191963 237730.85396825
# 2 liveness          0.86425     0.0239      0.19213998      0.17886120
# 3 loudness         -0.25300   -41.8250    -10.70272787     -9.37549702
# 4 speechiness       0.92000     0.0251      0.08167995      0.05893756
# 5 tempo           198.07500    56.4360    118.52444160    118.43584954
# 6 popularity       80.66667     0.0000     40.06326887     43.05936546
#   standard_deviation
# 1 96863.15635607
# 2     0.09095803
# 3     5.53604635
# 4     0.07552097
# 5    17.30560463
# 6    16.71171375

# %%
#Visualizations Relevant to Research



duration_plot <- ggplot(popularity_training, aes(x = duration_ms, y = popularity)) +
    geom_point() +
    labs(x="Duration (ms)", y= "Popularity Scale")

duration_plot #clear outlier (may need to delete)

liveness_plot <- ggplot(popularity_training, aes(x = liveness, y = popularity)) +
    geom_point() +
    labs(x="Liveness", y= "Popularity Scale")

liveness_plot

loudness_plot <- ggplot(popularity_training, aes(x = loudness, y = popularity)) +
    geom_point() +
    labs(x="loudness", y= "Popularity Scale")

loudness_plot

speechiness_plot <- ggplot(popularity_training, aes(x = speechiness, y = popularity)) +
    geom_point() +
    labs(x="speechiness", y= "Popularity Scale")

speechiness_plot

tempo_plot <- ggplot(popularity_training, aes(x = tempo, y = popularity)) +
    geom_point() +
    labs(x="tempo", y= "Popularity Scale")

energy_plot <- ggplot(popularity_training, aes(x = energy, y = popularity)) +
    geom_point() +
    labs(x="energy", y= "Popularity Scale")

energy_plot

acousticness_plot <- ggplot(popularity_training, aes(x = acousticness, y = popularity)) +
    geom_point() +
    labs(x="acousticness", y= "Popularity Scale")

acousticness_plot

danceability_plot <- ggplot(popularity_training, aes(x = danceability, y = popularity)) +
    geom_point() +
    labs(x="danceability", y= "Popularity Scale")

danceability_plot

instrumentalness_plot <- ggplot(popularity_training, aes(x = instrumentalness, y = popularity)) +
    geom_point() +
    labs(x="instrumentalness", y= "Popularity Scale")

instrumentalness_plot

tempo_plot
library(GGally)
pair_plot <- popularity_training%>%
select(popularity, duration_ms, energy, danceability, acousticness, loudness, instrumentalness, tempo, speechiness,liveness)%>%
ggpairs()

pair_plot
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
set.seed(4002)

popularity_recipe = recipe(popularity ~ energy + acousticness + loudness, data = popularity_training) %>%
    step_scale(all_predictors()) %>%
    step_center(all_predictors())

pop_spec = nearest_neighbor(weight_func = "rectangular", neighbors = tune()) %>%
    set_engine("kknn") %>%
    set_mode("regression")

pop_vfold = vfold_cv(popularity_training, v = 5, strata = popularity)

pop_wkflw = workflow() %>%
    add_recipe(popularity_recipe) %>%
    add_model(pop_spec)

pop_wkflw
# Out:
# ══ Workflow ════════════════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: nearest_neighbor()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 2 Recipe Steps
#
# ● step_scale()
# ● step_center()
#
# ── Model ───────────────────────────────────────────────────────────────────────
# K-Nearest Neighbor Model Specification (regression)
#
# Main Arguments:
#   neighbors = tune()
#   weight_func = rectangular
#
# Computational engine: kknn

# %%
set.seed(4002)
gridvals = tibble(neighbors = seq(1,200))

pop_results = pop_wkflw %>%
    tune_grid(resamples = pop_vfold, grid = gridvals) %>%
    collect_metrics()
pop_results
# Out:
#     neighbors .metric .estimator mean       n std_err     .config
# 1    1        rmse    standard   17.6448107 5 0.32901670  Model001
# 2    1        rsq     standard    0.1962481 5 0.01785158  Model001
# 3    2        rmse    standard   15.6762329 5 0.23815020  Model002
# 4    2        rsq     standard    0.2309617 5 0.01655812  Model002
# 5    3        rmse    standard   15.0377988 5 0.12688544  Model003
# 6    3        rsq     standard    0.2512927 5 0.01578076  Model003
# 7    4        rmse    standard   14.6175800 5 0.20601439  Model004
# 8    4        rsq     standard    0.2697604 5 0.02046534  Model004
# 9    5        rmse    standard   14.3975719 5 0.23949953  Model005
# 10   5        rsq     standard    0.2804955 5 0.02422476  Model005
# 11   6        rmse    standard   14.1687098 5 0.22599581  Model006
# 12   6        rsq     standard    0.2961040 5 0.02231791  Model006
# 13   7        rmse    standard   14.0166392 5 0.25026521  Model007
# 14   7        rsq     standard    0.3070687 5 0.02535666  Model007
# 15   8        rmse    standard   13.9684894 5 0.20993980  Model008
# 16   8        rsq     standard    0.3080893 5 0.02303193  Model008
# 17   9        rmse    standard   13.9458549 5 0.21319117  Model009
# 18   9        rsq     standard    0.3084809 5 0.02385096  Model009
# 19  10        rmse    standard   13.8418794 5 0.23466736  Model010
# 20  10        rsq     standard    0.3166733 5 0.02548284  Model010
# 21  11        rmse    standard   13.8314002 5 0.23167859  Model011
# 22  11        rsq     standard    0.3167677 5 0.02553002  Model011
# 23  12        rmse    standard   13.8308293 5 0.22746815  Model012
# 24  12        rsq     standard    0.3164761 5 0.02574837  Model012
# 25  13        rmse    standard   13.8249514 5 0.21320842  Model013
# 26  13        rsq     standard    0.3165879 5 0.02470752  Model013
# 27  14        rmse    standard   13.8042756 5 0.20445361  Model014
# 28  14        rsq     standard    0.3179651 5 0.02361475  Model014
# 29  15        rmse    standard   13.7629248 5 0.21954459  Model015
# 30  15        rsq     standard    0.3210997 5 0.02337649  Model015
# ⋮   ⋮         ⋮       ⋮          ⋮          ⋮ ⋮           ⋮
# 371 186       rmse    standard   14.2515836 5 0.155444386 Model186
# 372 186       rsq     standard    0.2728970 5 0.007724937 Model186
# 373 187       rmse    standard   14.2572660 5 0.156449213 Model187
# 374 187       rsq     standard    0.2723000 5 0.007987205 Model187
# 375 188       rmse    standard   14.2619547 5 0.155266210 Model188
# 376 188       rsq     standard    0.2718116 5 0.008067745 Model188
# 377 189       rmse    standard   14.2640034 5 0.155135596 Model189
# 378 189       rsq     standard    0.2716010 5 0.007869268 Model189
# 379 190       rmse    standard   14.2645840 5 0.156039496 Model190
# 380 190       rsq     standard    0.2715815 5 0.007913340 Model190
# 381 191       rmse    standard   14.2696833 5 0.156634154 Model191
# 382 191       rsq     standard    0.2710367 5 0.007702020 Model191
# 383 192       rmse    standard   14.2717851 5 0.156305559 Model192
# 384 192       rsq     standard    0.2708954 5 0.007898497 Model192
# 385 193       rmse    standard   14.2750182 5 0.155730643 Model193
# 386 193       rsq     standard    0.2706332 5 0.007790260 Model193
# 387 194       rmse    standard   14.2793511 5 0.154179756 Model194
# 388 194       rsq     standard    0.2701703 5 0.007924300 Model194
# 389 195       rmse    standard   14.2829291 5 0.154215835 Model195
# 390 195       rsq     standard    0.2698442 5 0.008071734 Model195
# 391 196       rmse    standard   14.2828810 5 0.152399800 Model196
# 392 196       rsq     standard    0.2699041 5 0.008001716 Model196
# 393 197       rmse    standard   14.2844997 5 0.153172902 Model197
# 394 197       rsq     standard    0.2697614 5 0.007956319 Model197
# 395 198       rmse    standard   14.2857059 5 0.150978632 Model198
# 396 198       rsq     standard    0.2696079 5 0.007899025 Model198
# 397 199       rmse    standard   14.2852945 5 0.150124878 Model199
# 398 199       rsq     standard    0.2696885 5 0.007705880 Model199
# 399 200       rmse    standard   14.2860113 5 0.149864579 Model200
# 400 200       rsq     standard    0.2696406 5 0.007805590 Model200

# %%
pop_min = pop_results %>% 
    filter(.metric == "rmse") %>%
    arrange(mean) %>%
    slice(1)
pop_min
# Out:
#   neighbors .metric .estimator mean     n std_err   .config
# 1 25        rmse    standard   13.68202 5 0.1408205 Model025

# %%
set.seed(4002)
kmin = pop_min %>%
    pull(neighbors)

pop_spec = nearest_neighbor(weight_func = "rectangular", neighbors = kmin) %>%
    set_engine("kknn") %>%
    set_mode("regression")

pop_fit = workflow() %>%
    add_recipe(popularity_recipe) %>%
    add_model(pop_spec) %>%
    fit(data = popularity_training)

pop_summary = pop_fit %>%
    predict(popularity_testing) %>%
    bind_cols(popularity_testing) %>%
    metrics(truth = popularity, estimate = .pred)

pop_summary
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   13.1689588
# 2 rsq     standard    0.3940366
# 3 mae     standard    9.4318324
